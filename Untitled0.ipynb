# %% [markdown]
# <a href="https://colab.research.google.com/github/svj1010ibm/clinicaltrial/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install generative-ai-hub-sdk
# !pip install langchain
# Out:
# Collecting generative-ai-hub-sdk
#   Downloading generative_ai_hub_sdk-1.2.2-py3-none-any.whl (202 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 202.2/202.2 kB 1.8 MB/s eta 0:00:00
# Collecting langchain[openai]~=0.1.0 (from generative-ai-hub-sdk)
#   Downloading langchain-0.1.20-py3-none-any.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 12.0 MB/s eta 0:00:00
# Collecting openai>=1.3.3 (from generative-ai-hub-sdk)
#   Downloading openai-1.33.0-py3-none-any.whl (325 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.5/325.5 kB 31.2 MB/s eta 0:00:00
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.10/dist-packages (from generative-ai-hub-sdk) (8.1.7)
# Collecting ai-core-sdk>=2.1 (from generative-ai-hub-sdk)
#   Downloading ai_core_sdk-2.1.1-py3-none-any.whl (147 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.1/147.1 kB 12.8 MB/s eta 0:00:00
# Collecting overloading==0.5.0 (from generative-ai-hub-sdk)
#   Downloading overloading-0.5.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: pydantic>=2.5.3 in /usr/local/lib/python3.10/dist-packages (from generative-ai-hub-sdk) (2.7.3)
# Collecting langchain-openai~=0.0.2 (from generative-ai-hub-sdk)
#   Downloading langchain_openai-0.0.8-py3-none-any.whl (32 kB)
# Collecting ai-api-client-sdk==2.0.4 (from ai-core-sdk>=2.1->generative-ai-hub-sdk)
#   Downloading ai_api_client_sdk-2.0.4-py3-none-any.whl (251 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.0/251.0 kB 27.1 MB/s eta 0:00:00
# Collecting aenum~=3.1 (from ai-api-client-sdk==2.0.4->ai-core-sdk>=2.1->generative-ai-hub-sdk)
#   Downloading aenum-3.1.15-py3-none-any.whl (137 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.6/137.6 kB 15.6 MB/s eta 0:00:00
# Collecting pyhumps~=3.0 (from ai-api-client-sdk==2.0.4->ai-core-sdk>=2.1->generative-ai-hub-sdk)
#   Downloading pyhumps-3.8.0-py3-none-any.whl (6.1 kB)
# Requirement already satisfied: requests<3.0 in /usr/local/lib/python3.10/dist-packages (from ai-api-client-sdk==2.0.4->ai-core-sdk>=2.1->generative-ai-hub-sdk) (2.31.0)
# Collecting langchain-core<0.2.0,>=0.1.27 (from langchain-openai~=0.0.2->generative-ai-hub-sdk)
#   Downloading langchain_core-0.1.52-py3-none-any.whl (302 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.9/302.9 kB 23.7 MB/s eta 0:00:00
# Collecting tiktoken<1,>=0.5.2 (from langchain-openai~=0.0.2->generative-ai-hub-sdk)
#   Downloading tiktoken-0.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 46.0 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain[openai]~=0.1.0->generative-ai-hub-sdk) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain[openai]~=0.1.0->generative-ai-hub-sdk) (2.0.30)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain[openai]~=0.1.0->generative-ai-hub-sdk) (3.9.5)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain[openai]~=0.1.0->generative-ai-hub-sdk) (4.0.3)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain[openai]~=0.1.0->generative-ai-hub-sdk)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Collecting langchain-community<0.1,>=0.0.38 (from langchain[openai]~=0.1.0->generative-ai-hub-sdk)
#   Downloading langchain_community-0.0.38-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 67.9 MB/s eta 0:00:00
# Collecting langchain-text-splitters<0.1,>=0.0.1 (from langchain[openai]~=0.1.0->generative-ai-hub-sdk)
#   Downloading langchain_text_splitters-0.0.2-py3-none-any.whl (23 kB)
# Collecting langsmith<0.2.0,>=0.1.17 (from langchain[openai]~=0.1.0->generative-ai-hub-sdk)
#   Downloading langsmith-0.1.77-py3-none-any.whl (125 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.2/125.2 kB 15.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain[openai]~=0.1.0->generative-ai-hub-sdk) (1.25.2)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain[openai]~=0.1.0->generative-ai-hub-sdk) (8.3.0)
# Collecting tiktoken<1,>=0.5.2 (from langchain-openai~=0.0.2->generative-ai-hub-sdk)
#   Downloading tiktoken-0.5.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 67.2 MB/s eta 0:00:00
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai>=1.3.3->generative-ai-hub-sdk) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai>=1.3.3->generative-ai-hub-sdk) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from openai>=1.3.3->generative-ai-hub-sdk)
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 7.8 MB/s eta 0:00:00
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai>=1.3.3->generative-ai-hub-sdk) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai>=1.3.3->generative-ai-hub-sdk) (4.66.4)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.10/dist-packages (from openai>=1.3.3->generative-ai-hub-sdk) (4.12.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.5.3->generative-ai-hub-sdk) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.5.3->generative-ai-hub-sdk) (2.18.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain[openai]~=0.1.0->generative-ai-hub-sdk) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain[openai]~=0.1.0->generative-ai-hub-sdk) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain[openai]~=0.1.0->generative-ai-hub-sdk) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain[openai]~=0.1.0->generative-ai-hub-sdk) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain[openai]~=0.1.0->generative-ai-hub-sdk) (1.9.4)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai>=1.3.3->generative-ai-hub-sdk) (3.7)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai>=1.3.3->generative-ai-hub-sdk) (1.2.1)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain[openai]~=0.1.0->generative-ai-hub-sdk)
#   Downloading marshmallow-3.21.3-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.2/49.2 kB 6.4 MB/s eta 0:00:00
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain[openai]~=0.1.0->generative-ai-hub-sdk)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai>=1.3.3->generative-ai-hub-sdk) (2024.6.2)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai>=1.3.3->generative-ai-hub-sdk)
#   Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 8.8 MB/s eta 0:00:00
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.3.3->generative-ai-hub-sdk)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.2 MB/s eta 0:00:00
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<0.2.0,>=0.1.27->langchain-openai~=0.0.2->generative-ai-hub-sdk)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Collecting packaging<24.0,>=23.2 (from langchain-core<0.2.0,>=0.1.27->langchain-openai~=0.0.2->generative-ai-hub-sdk)
#   Downloading packaging-23.2-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 6.7 MB/s eta 0:00:00
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.2.0,>=0.1.17->langchain[openai]~=0.1.0->generative-ai-hub-sdk)
#   Downloading orjson-3.10.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (142 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.7/142.7 kB 12.0 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0->ai-api-client-sdk==2.0.4->ai-core-sdk>=2.1->generative-ai-hub-sdk) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0->ai-api-client-sdk==2.0.4->ai-core-sdk>=2.1->generative-ai-hub-sdk) (2.0.7)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain[openai]~=0.1.0->generative-ai-hub-sdk) (3.0.3)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken<1,>=0.5.2->langchain-openai~=0.0.2->generative-ai-hub-sdk) (2024.5.15)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core<0.2.0,>=0.1.27->langchain-openai~=0.0.2->generative-ai-hub-sdk)
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain[openai]~=0.1.0->generative-ai-hub-sdk)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: pyhumps, overloading, aenum, packaging, orjson, mypy-extensions, jsonpointer, h11, typing-inspect, tiktoken, marshmallow, jsonpatch, httpcore, ai-api-client-sdk, langsmith, httpx, dataclasses-json, ai-core-sdk, openai, langchain-core, langchain-text-splitters, langchain-openai, langchain-community, langchain, generative-ai-hub-sdk
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.0
#     Uninstalling packaging-24.0:
#       Successfully uninstalled packaging-24.0
# Successfully install
167555, 0.016155899031181992, 0.001217972405487347, -0.02919167363343628, 0.03604008360041842, -0.0034407306045563875, -0.014490070234196815, 0.014238873902216717, 0.019937066929174484, 0.029879159213792698, 0.012863903672826483, -0.011845896357937672, -0.007998624113038703, 0.010173457033129586, 0.04804463076346068, 0.005106559634372216, 7.147531345109741e-05, -0.010609745350183305, 0.0069673966738266774, -0.00659060217585653, -0.0024656917205164793, 0.00828287308413334, 0.009770220423867807, -0.0020608027121296235, 0.010080910574931476, 0.0027780347363665255, -0.01050397876766198, 0.0015666727422867612, 0.042174564013107305, 0.036410265707920456, -0.041460638184104455, 0.012784578270274188, 0.0077474277810586035, -6.269582987758074e-05, 0.012949838671879084, -0.0057114145482648855, -0.006567465794137652, 0.030434436100336158, -0.018337341547773185, -0.004029058966061137, -0.014080223097112127, 0.013386127920255403, 0.0026573942334130072, 0.0011204685170833563, -0.015508076617763024, -0.004273645235879627, 0.009479361856272862, 0.028874373885872304, -0.00548004933409221, 0.006246859385678321, 0.012434224952273072, -0.017451543858019933, 0.0453740147759099, 0.008567122055227978, 0.013134931588275304, 0.009307489995522457, -0.01857531868675267, 0.025846794983820108, 0.004005922584342259, -0.006074988456250517, -0.014741266566176914, -0.008335756375394002, 0.008514237832644714, 0.0015592360149013149, 0.0054899651258265725, -0.0019302465338570682, -0.01688304777847586, 0.009366983814606027, -0.007192151360176444, 0.014807370913083392, -0.030064250267543717, 0.03178296328711216, 0.030407993989044525, 0.016684733806433823, 0.01348528397495382, -0.01431819837344641, 0.00859356323519701, -0.008077949515590996, 0.013776143473871367, -0.014212431790925085, -0.02080964356328192, 0.04518892372215889, 0.020307250899321724, -0.004832226920673241, 0.010695681280558507, 0.012923397491910054, -0.009294268939876641, -0.01961976718161051, -0.0007234293358632158, -0.017292893052915342, 0.023176178996269333, 0.012064040982125832, 0.003913376591805449, 0.009664453841346482, 0.016645070639496374, -0.044 ...

# %%
# !pip install PyPDF
# Out:
# Collecting PyPDF
#   Downloading pypdf-4.2.0-py3-none-any.whl (290 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.4/290.4 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: typing_extensions>=4.0 in /usr/local/lib/python3.10/dist-packages (from PyPDF) (4.12.1)
# Installing collected packages: PyPDF
# Successfully installed PyPDF-4.2.0

# %%
from langchain.document_loaders import PyPDFLoader
from langchain.text_splitter import CharacterTextSplitter
from gen_ai_hub.proxy.langchain.init_models import init_embedding_model
from gen_ai_hub.proxy.core.proxy_clients import get_proxy_client
from langchain.document_loaders import PyPDFDirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.llms import OpenAI
from gen_ai_hub.proxy.langchain.openai import ChatOpenAI
from langchain.chains import RetrievalQA
from langchain.prompts import PromptTemplate
from gen_ai_hub.proxy.langchain.init_models import init_embedding_model
from langchain_community.vectorstores.hanavector import HanaDB
pdf_folder_path = "dataset"
documents = []
embeddings = init_embedding_model('text-embedding-ada-002')
for file in os.listdir(pdf_folder_path):
    if file.endswith('.pdf'):
        pdf_path = os.path.join(pdf_folder_path, file)
        loader = PyPDFLoader(pdf_path)
        documents.extend(loader.load())
text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=10)
texts = text_splitter.split_documents(documents)
doc_vectors = embeddings.embed_documents([t.page_content for t in texts])
print(doc_vectors)
# Out:
004587995752885178, 0.011228599421954923, -0.020986482195187527, -0.0032052024731832472, 0.00841505533859271, 0.004095625072635511, 0.010614734919649508, -0.004885335847320422, -0.0079098957369348, 0.0042842607320845326, 0.016702221463102993, -0.014259554237934702, 0.03314866822333137, -0.030923408936812967, 0.016561545190257442, -0.005393692213669113, 0.023697716769928916, -0.0010087195404019094, 0.005371312066865969, -0.0181473602690088 ...

# %%
from langchain.docstore.document import Document
from langchain_community.vectorstores.hanavector import HanaDB
from gen_ai_hub.proxy.langchain.init_models import init_embedding_model

# %%
# !pip install hdbcli
# Out:
# Collecting hdbcli
#   Downloading hdbcli-2.20.23-cp34-abi3-manylinux1_x86_64.whl (10.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 41.2 MB/s eta 0:00:00
# Installing collected packages: hdbcli
# Successfully installed hdbcli-2.20.23

# %%
from hdbcli import dbapi
conn = dbapi.connect(
    address="ba303a35-d11f-44a3-9c31-7613dea961f5.hana.prod-eu10.hanacloud.ondemand.com",
    port="443",
    user="DBADMIN",
    password="Ibmcanhana1",
    autocommit=True,
    sslValidateCertificate=False,
)

# %%
pip install --upgrade langchain
# Out:
# Requirement already satisfied: langchain in /usr/local/lib/python3.10/dist-packages (0.1.20)
# Collecting langchain
#   Downloading langchain-0.2.3-py3-none-any.whl (974 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 974.0/974.0 kB 4.7 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.0.30)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (3.9.5)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (4.0.3)
# Collecting langchain-core<0.3.0,>=0.2.0 (from langchain)
#   Downloading langchain_core-0.2.5-py3-none-any.whl (314 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 314.7/314.7 kB 24.6 MB/s eta 0:00:00
# Collecting langchain-text-splitters<0.3.0,>=0.2.0 (from langchain)
#   Downloading langchain_text_splitters-0.2.1-py3-none-any.whl (23 kB)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.1.77)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (1.25.2)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.7.3)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (8.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3.0,>=0.2.0->langchain) (1.33)
# Requirement already satisfied: packaging<24.0,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3.0,>=0.2.0->langchain) (23.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.4)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain) (2.18.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain) (4.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2024.6.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.3)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.0->langchain) (3.0.0)
# Installing collected packages: langchain-core, langchain-text-splitters, langchain
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.1.52
#     Uninstalling langchain-core-0.1.52:
#       Successfully uninstalled langchain-core-0.1.52
#   Attempting uninstall: langchain-text-splitters
#     Found existing installation: langchain-text-splitters 0.0.2
#     Uninstalling langchain-text-splitters-0.0.2:
#       Successfully uninstalled langchain-text-splitters-0.0.2
#   Attempting uninstall: langchain
#     Found existing installation: langchain 0.1.20
#     Uninstalling langchain-0.1.20:
#       Successfully uninstalled langchain-0.1.20
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# generative-ai-hub-sdk 1.2.2 requires langchain[openai]~=0.1.0, but you have langchain 0.2.3 which is incompatible.
# langchain-community 0.0.38 requires langchain-core<0.2.0,>=0.1.52, but you have langchain-core 0.2.5 which is incompatible.
# langchain-openai 0.0.8 requires langchain-core<0.2.0,>=0.1.27, but you have langchain-core 0.2.5 which is incompatible.
# Successfully installed langchain-0.2.3 langchain-core-0.2.5 langchain-text-splitters-0.2.1

# %%
#from gen_ai_hub_proxy.langchain.init_models import  init_embedding_model
from langchain_community.vectorstores.hanavector import HanaDB
db = HanaDB(embedding=embeddings, connection=conn, table_name= "ClinicalTrial")
db.delete(filter={})
db.add_documents(texts)
print(texts)
print('chunks added to table')
# Out:
# [Document(page_content='Introducing a research study for a potential mRNA shingles vaccine:  \nThe mRNA Shingles Vaccine Study will help us learn if an investigational vaccine is safe and can help the \nbody produce antibodies which may help prevent shingles (also known as herpes zoster)  \n \nWho may participate: Participating in a clinical trial is an important and personal decision. Thank you for \ntaking the time to learn more about the mRNA Shingles Vaccine Study.  \n \nThis study is enrolling people who:  \n• Are 50 to 69 years old  \n• Are generally healthy or have stable chronic conditions  \n• Do not have a history of shingles or heart disease  \n• Have not previously received a chickenpox or shingles vaccine  \n• Have not had an RNA vaccine in the last month and do not plan to have an RNA vaccine within \none month prior to receiving the study vaccine  \nCondition:  Healthy volunteers  \nAge: 50 to 69 years old  \nSex: Male or Female  \n \nWhat to expect:  \nStudy participants will be randomly placed into groups that will receive either the investigational shingles \nvaccine or a licensed shingles vaccine (comparator). Participants in the investigational shingles vaccine \ngroups will receive one of three differen t candidates (which means it may be prepared differently) at one \nof three different dose levels.  \nThe study vaccines will be given in two separate injections (shots) into the muscle in the upper arm. \nParticipants will receive the second injection about two or six months after their first injection, \ndepending on the group they are assigned.  \n \nLength of study treatment:  \nEither about one or five years, depending on your study group  \nNumber of study: visits Up to 17  \n \nLength of follow -up period:  \nUp to five years, depending on your study group', metadata={'source': 'dataset/Shingles Clinical Trial _ Pfizer.pdf', 'page': 0}), Document(page_content='About shingles:  \nShingles (also known as herpes zoster) is a viral infection caused by the varicella zoster virus (the same \nvirus that causes chickenpox). After recovering from chickenpox, the virus stays in the body but is \ninactive. If it becomes active, it can lead to symptoms such as fever, and/or a painful rash.  \n \nAlmost 1 in 3 adults in the United States will develop shingles in their lifetime. Anyone who has had \nchickenpox is at risk for shingles, but after 50 years of age, a person’s risk for shingles and shingles -\nrelated complications, such as long -term nerve pa in or vision loss, greatly increases.  \n \nWhile vaccines have been developed to help prevent shingles, they aren’t always recommended for \npeople with certain medical conditions (like a weakened immune system). That’s why we’re working to \nunderstand if an mRNA -based vaccine has the potential to be a safer option for the prevention of \nshingles.  \n \nFrequently asked questions:  \n \nWhat is the investigational vaccine?  \nThe investigational vaccine is a modified RNA (mRNA) vaccine, which does not contain any killed or \nweakened virus. mRNA vaccines work by telling your body to produce proteins that look just like certain \nparts of the virus. The immune system reacts to these  proteins in a similar way to a real virus. As a result, \ncertain immune system cells “remember” how to recognize these proteins quickly and fight the real \ninfection if it happens in the future.  \nInvestigational means that the vaccine we are researching has not yet been approved for use in patients \nwith shingles.  \nThis means it is not available to patients with this condition except to those who are participating in a \nstudy.  \n \nHow will the study vaccines be given?  \nThe study vaccines will be given in two separate injections (shots) into the muscle in the upper arm.  \n \nWhat is an active -controlled study?', metadata={'source': 'dataset/Shingles Clinical Trial _ Pfizer.pdf', 'page': 1}), Document(page_content='A research study that’s active -controlled uses a comp ...
# chunks added to table

# %%
#Get Embeddings
from gen_ai_hub.proxy.native.openai import embeddings
def get_embedding(input, model="text-embedding-ada-002") -> str:
response = embeddings.create(
    model_name = model,
    input=input
)
return  response.data[0].embedding
# Out:
#   File "<ipython-input-17-3ffab44e9c3f>", line 4
#     response = embeddings.create(
#     ^
# IndentationError: expected an indented block after function definition on line 3

# %%
import requests
import json
import sklearn
from sklearn.metrics.pairwise import cosine_similarity
def run_vector_search(query:str, metric:"COSINE_SIMILARITY", k=4):
    if metric == 'L2DISTANCE':
        sort = 'ASC'
    else :
        sort = 'DESC'
        query_vector = get_embedding(query)
        sql = '''SELECT TOP 2 "VEC_TEXT" FROM "DBADMIN"."CT"
        ORDER BY "COSINE_SIMILARITY"("VEC_VECTOR", TO_REAL_VECTOR('{qv}')) {sort}'''.format(k=4,metric="COSINE_SIMILARITY",qv=query_vector,sort=sort)
        hdf = cc.sql(sql)
        df_context = hdf.head(k).collect()
        run
        df_context

# %%
query = "what is clinical trial?"
df_context = run_vector_search(query=query,metric="COSINE_SIMILARITY", k=4)
df_context
